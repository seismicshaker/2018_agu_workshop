# %%
from data_analysis import *
import matplotlib.pyplot as plt

# %%
# Define the URL
place = 'Canada'
data = download_data(place)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-67e1abc731c3> in <module>()
#       1 # Define the URL
#       2 place = 'Canada'
# ----> 3 data = download_data(place)
#
# NameError: name 'download_data' is not defined

# %%
decimal_year = data[:, 0] + 1/12*(data[:, 1] - 1)
temperature_anomaly = data[:, 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-65c768a678b2> in <module>()
# ----> 1 decimal_year = data[:, 0] + 1/12*(data[:, 1] - 1)
#       2 temperature_anomaly = data[:, 2]
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.title("Temperature anomaly for {}".format(place))
plt.plot(decimal_year, temperature_anomaly)
plt.xlabel('year')
plt.ylabel('temperature anomaly (C)')
plt.grid()
plt.xlim(decimal_year.min(), decimal_year.max())
# Out:
# (1743.8333333333333, 2013.6666666666667)

# %%
moving_avg = moving_avgerage(temperature_anomaly, 6)

plt.figure(figsize=(10, 6))
plt.title("Temperature anomaly for {}".format(place))
plt.plot(decimal_year, temperature_anomaly, label="anomaly")
plt.plot(decimal_year, moving_avg, label="12-month moving average", linewidth=3)
plt.xlabel('year')
plt.ylabel('temperature anomaly (C)')
plt.legend()
plt.grid()
plt.xlim(decimal_year.min(), decimal_year.max())
# Out:
# (1743.8333333333333, 2013.6666666666667)

# %%
test_moving_avg()
